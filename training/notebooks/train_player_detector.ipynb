# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # Train Soccer Player Detector
#
# ---
#
# [![Download Dataset](https://app.roboflow.com/images/download-dataset-badge.svg)](https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc)
#
# This notebook is based on the [How to Train YOLOv8 Object Detection on a Custom Dataset](https://github.com/roboflow/notebooks/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb) notebook from the [roboflow/notebooks](https://github.com/roboflow/notebooks) repository.

# %% [markdown]
# ## Configure API keys
#
# - Open your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sat Nov 22 01:08:21 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.42                 Driver Version: 581.42         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   39C    P8              3W /  140W |     396MiB /   8188MiB |     19%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1964    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A            3208    C+G   ...0_x64__8j3eq9eme6ctt\IGCC.exe      N/A      |
# |    0   N/A  N/A            8588    C+G   ...Claude\app-1.0.734\claude.exe      N/A      |
# |    0   N/A  N/A           12760    C+G   ...Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A           13740    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           15528    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           15564    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           16656    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           17860    C+G   ...mba6cd70vzyy\ArmouryCrate.exe      N/A      |
# |    0   N/A  N/A           24136    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           25532    C+G   ...Browser\Application\brave.exe      N/A      |
# |    0   N/A  N/A           25948    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           26240    C+G   ...4__cv1g1gvanyjgm\WhatsApp.exe      N/A      |
# |    0   N/A  N/A           28980    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           29228    C+G   ...t\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A           30288    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           31324    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           32600    C+G   ....0.3595.90\msedgewebview2.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks

# %% [markdown]
# ## 📁 Dataset Local FOOTAR - 👤 PLAYERS/KEEPERS/REFEREES
#
# - Modelo final: distingue entre jogadores, guarda-redes e árbitros
#
# **🎯 Treino multi-classe para deteção de pessoas no campo**- **Classe ignorada**: ball (0) - já tem modelo dedicado
#
# - Dataset completo tem 4 classes, mas vamos treinar **3 classes** (ignorar ball)- **Classes treinadas**: goalkeeper (1), player (2), referee (3)

# %%
import os

# Path to local FOOTAR dataset (tem 4 classes, treinaremos 3)
DATASET_PATH = r"C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1"
DATA_YAML = os.path.join(DATASET_PATH, "data.yaml")

print(f"✅ Dataset path: {DATASET_PATH}")
print(f"👤 CLASSES A TREINAR: goalkeeper, player, referee (classes 1, 2, 3)")
print(f"❌ Classe ignorada: ball (class 0 - tem modelo dedicado)")

print(f"✅ data.yaml: {DATA_YAML}")
print(f"✅ Dataset exists: {os.path.exists(DATA_YAML)}")
# Out:
# ✅ Dataset path: C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1
# 👤 CLASSES A TREINAR: goalkeeper, player, referee (classes 1, 2, 3)
# ❌ Classe ignorada: ball (class 0 - tem modelo dedicado)
# ✅ data.yaml: C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1\data.yaml
# ✅ Dataset exists: True

# %% [markdown]
# ## 📊 Dataset Info
#
# **Dataset FOOTAR**: `football-players-and-ball-1`
# - **4 classes totais**: ball, goalkeeper, player, referee
# - **3 classes treinadas**: goalkeeper (1), player (2), referee (3)
# - **1 classe ignorada**: ball (0)
#
# - **708** imagens de treino- 👔 **Referee** (árbitros com equipamento distinto)
#
# - **Dataset local** (sem download necessário)- 👕 **Player** (jogadores de campo)
#
# - ⚽ **Goalkeeper** (guarda-redes com equipamento diferente)
# **🎯 Objetivo**: Modelo que distingue entre:

# %%
import yaml

# Read data.yaml
with open(DATA_YAML, 'r') as f:
    data_config = yaml.safe_load(f)

print("📋 Dataset Configuration:")
print(f"  Classes: {data_config['nc']}")
print(f"  Names: {data_config['names']}")
print(f"  Train: {data_config['train']}")
print(f"  Val: {data_config['val']}")
print(f"  Test: {data_config['test']}")

# Verify paths exist
train_path = os.path.join(DATASET_PATH, "train", "images")
val_path = os.path.join(DATASET_PATH, "valid", "images")
print(f"\n✅ Train images: {len(os.listdir(train_path))}")
print(f"✅ Val images: {len(os.listdir(val_path))}")
# Out:
# 📋 Dataset Configuration:
#   Classes: 4
#   Names: ['ball', 'goalkeeper', 'player', 'referee']
#   Train: ../train/images
#   Val: ../valid/images
#   Test: ../test/images
#
# ✅ Train images: 708
# ✅ Val images: 202

# %% [markdown]
# ## Custom training - YOLOv12l Optimized (8GB VRAM)
#
# **⚠️ CONFIGURAÇÃO ADAPTADA PARA 8GB VRAM:**
#
# **Modelo & Hardware:**
# - 🎯 **Model: yolo12l** - 43M parâmetros (Large - máxima precisão que cabe em 8GB)
# - ✅ **epochs: 100** - Mais tempo para convergência (multi-classe)
# - ✅ **imgsz: 1280** - Resolução alta (crítica para jogadores distantes)
# - ✅ **batch: 2** - Máximo estável para YOLOv12l em 8GB
# - ✅ **optimizer: SGD** - Usa metade da VRAM do AdamW
# - ✅ **cos_lr: True** - Cosine learning rate para ajuste fino
#
# **Classes (3):**
# - 🥅 **Goalkeeper** - Guarda-redes
# - ⚽ **Player** - Jogadores de campo
# - 🟨 **Referee** - Árbitros
#
# **Augmentations Balanceados:**
# - ✅ **mosaic: 1.0** - Default (bom para multi-objeto)
# - ✅ **mixup: 0.1** - Ajuda com oclusões
# - ✅ **degrees: 10.0** - Rotação moderada (campo pode ter ângulos)
# - ✅ **scale: 0.5** - Variação de escala (jogadores perto vs longe)
# - ✅ **fliplr: 0.5** - Flip horizontal (campo simétrico)
#
# **Meta esperada:** mAP50 > 85%, mAP50-95 > 60%

# %%
import gc
import torch

# 🧹 LIMPEZA CRÍTICA: Liberta VRAM presa do treino anterior
gc.collect()
torch.cuda.empty_cache()

# Verifica memória disponível
print(f"✅ VRAM limpa!")
print(f"📊 Memória GPU livre: {torch.cuda.mem_get_info()[0] / 1024**3:.2f} GB")
print(f"📊 Memória GPU total: {torch.cuda.mem_get_info()[1] / 1024**3:.2f} GB")
print("\n⚠️ Se ainda mostrar 0 bytes livres, REINICIA O KERNEL (Ctrl+Shift+P → 'Restart Kernel')\n")
# Out:
# ✅ VRAM limpa!
# 📊 Memória GPU livre: 6.93 GB
# 📊 Memória GPU total: 8.00 GB
#
# ⚠️ Se ainda mostrar 0 bytes livres, REINICIA O KERNEL (Ctrl+Shift+P → 'Restart Kernel')

# %%
import os
import gc
import torch
from ultralytics import YOLO

# VRAM cleanup before training
gc.collect()
torch.cuda.empty_cache()

# Download and initialize YOLOv12m pretrained model (MEDIUM - perfeito para pessoas)
model = YOLO('yolo12m.pt')

# Start training with YOLOv12m configuration
# RTX 4060 Laptop 8GB optimized settings - BALANCED CONFIG
results = model.train(
    data=DATA_YAML,           # Use local FOOTAR dataset
    epochs=100,               # 100 epochs for best performance
    imgsz=640,                # 640px - resolução PADRÃO YOLO (perfeita para pessoas)
    batch=8,                  # Batch 8 (graças à redução de 1280→640)
    device=0,                 # GPU device
    classes=[1, 2, 3],        # 👤 CRÍTICO: treina APENAS goalkeeper, player, referee (ignora ball)
    
    # Optimizer Configuration (SGD for better generalization)
    optimizer='SGD',
    lr0=0.01,                 # Initial learning rate
    lrf=0.01,                 # Final learning rate (OneCycleLR)
    momentum=0.937,           # SGD momentum
    weight_decay=0.0005,      # Weight decay (L2 regularization)
    
    # Training Augmentations
    hsv_h=0.015,              # HSV-Hue augmentation
    hsv_s=0.7,                # HSV-Saturation augmentation
    hsv_v=0.4,                # HSV-Value augmentation
    degrees=0.0,              # Rotation augmentation (disabled)
    translate=0.1,            # Translation augmentation
    scale=0.5,                # Scale augmentation
    shear=0.0,                # Shear augmentation (disabled)
    perspective=0.0,          # Perspective augmentation (disabled)
    flipud=0.0,               # Flip up-down prob (disabled)
    fliplr=0.5,               # Flip left-right prob
    mosaic=1.0,               # Mosaic augmentation prob
    mixup=0.0,                # Mixup augmentation prob
    copy_paste=0.0,           # Copy-paste augmentation prob
    
    # Loss Configuration
    box=7.5,                  # Box loss gain
    cls=0.5,                  # Classification loss gain
    dfl=1.5,                  # Distribution Focal Loss gain
    
    # Validation & Checkpointing
    val=True,                 # Validate during training
    save=True,                # Save checkpoints
    save_period=10,           # Save checkpoint every N epochs
    plots=True,               # Generate training plots
    
    # Output Configuration
    project='runs/detect',    # Project directory
    name='player_y12m_footar_640', # Run name (OTIMIZADO: Medium + 640px)
    exist_ok=False,           # Don't overwrite existing runs
    
    # Performance (OTIMIZADO)
    workers=0,                # Single-threaded (remove multiprocessing overhead)
    cache=False,              # Don't cache images (saves RAM)
    amp=True,                 # Use Automatic Mixed Precision
    verbose=True,             # Verbose output
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.230 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Ultralytics 8.3.221  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=[1, 2, 3], close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1\data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=player_y12m_footar_640, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=[1, 2, 3], close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1\data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=player_y12m_footar_640, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1414108  ultralytics.nn.modules.head.Detect           [4, [256, 512, 512]]
#  21        [14, 17, 20]  1   1414108  ultralytics.nn.modules.head.Detect           [4, [256, 512, 512]]
# YOLOv12m summary: 292 layers, 20,140,572 parameters, 20,140,556 gradients, 67.8 GFLOPs
#
# YOLOv12m summary: 292 layers, 20,140,572 parameters, 20,140,556 gradients, 67.8 GFLOPs
#
# Transferred 745/751 items from pretrained weights
# Transferred 745/751 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 1347.0395.8 MB/s, size: 199.7 KB)
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 1347.0395.8 MB/s, size: 199.7 KB)
# train: Scanning C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1\train\labels.cache... 708 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 708/708 593.0Kit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 1640.7226.4 MB/s, size: 222.5 KB)
# train: Scanning C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1\train\labels.cache... 708 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 708/708 593.0Kit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 1640.7226.4 MB/s, size: 222.5 KB)
# val: Scanning C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1\valid\labels.cache... 202 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 202/202  0.0s
# val: Scanning C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1\valid\labels.cache... 202 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 202/202  0.0s
# Plotting labels to C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640\labels.jpg...
# Plotting labels to C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640\labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 123 weight(decay=0.0), 130 weight(decay=0.0005), 129 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      5.86G     0.9115      1.338     0.8618        131        640: 100% ━━━━━━━━━━━━ 89/89 2.2it/s 40.4s0.4ss
#       1/100      5.86G     0.9115      1.338     0.8618        131        640: 100% ━━━━━━━━━━━━ 89/89 2.2it/s 40.4s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.2it/s 4.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.2it/s 4.0s
#                    all        202       3023      0.733      0.727      0.783      0.546
#                    all        202       3023      0.733      0.727      0.783      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      5.81G      1.064      0.884     0.8775        101        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 39.0s0.3ss
#       2/100      5.81G      1.064      0.884     0.8775        101        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 39.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.2it/s 4.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.2it/s 4.0s
#                    all        202       3023      0.836      0.834      0.903      0.517
#                    all        202       3023      0.836      0.834      0.903      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      5.83G       1.21      1.081     0.9172         92        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.8s0.3ss
#       3/100      5.83G       1.21      1.081     0.9172         92        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.8s0.3s
#                    all        202       3023      0.783       0.82      0.847      0.508
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.8s
#                    all        202       3023      0.783       0.82      0.847      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      5.84G      1.317      1.033     0.9413        124        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.6s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s0.3s
#                    all        202       3023      0.903      0.844      0.904      0.469
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s
#                    all        202       3023      0.903      0.844      0.904      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100       5.8G      1.255     0.7616     0.9355        184        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.6s0.3ss
#       5/100       5.8G      1.255     0.7616     0.9355        184        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.866      0.872      0.919      0.553
#                    all        202       3023      0.866      0.872      0.919      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      5.82G      1.157     0.6884     0.9088        105        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.3ss
#       6/100      5.82G      1.157     0.6884     0.9088        105        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.904      0.887      0.941      0.609
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.904      0.887      0.941      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100       5.8G      1.128     0.6198     0.9078         92        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.4ss
#       7/100       5.8G      1.128     0.6198     0.9078         92        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.919      0.887      0.933      0.674
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.919      0.887      0.933      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      5.91G      1.041     0.5917     0.8993         32        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.4ss
#       8/100      5.91G      1.041     0.5917     0.8993         32        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.931      0.884      0.942      0.643
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.931      0.884      0.942      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      5.83G      1.007       0.55     0.8879        122        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.0s0.3ss
#       9/100      5.83G      1.007       0.55     0.8879        122        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.0s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.909      0.881      0.929      0.639
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.909      0.881      0.929      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      5.81G     0.9692     0.5383     0.8869        164        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.0s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.942      0.885      0.951      0.694
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.942      0.885      0.951      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100       5.8G     0.9456      0.532     0.8777        120        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3ss
#      11/100       5.8G     0.9456      0.532     0.8777        120        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s0.3s
#                    all        202       3023      0.952      0.872      0.945      0.707
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s
#                    all        202       3023      0.952      0.872      0.945      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      5.84G     0.9347      0.515     0.8736         92        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.0s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.919      0.894      0.946      0.745
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.919      0.894      0.946      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      5.82G     0.9114     0.5038     0.8705         73        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.923      0.937      0.958      0.709
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.923      0.937      0.958      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      5.83G     0.8816     0.4986       0.87        122        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#      14/100      5.83G     0.8816     0.4986       0.87        122        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.934      0.878      0.943      0.739
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.934      0.878      0.943      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      5.84G     0.8852     0.4965      0.862         88        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.4ss
#      15/100      5.84G     0.8852     0.4965      0.862         88        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.8s0.3s
#                    all        202       3023      0.953      0.894      0.957      0.749
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.8s
#                    all        202       3023      0.953      0.894      0.957      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      5.92G     0.8747     0.4993     0.8622         86        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3ss
#      16/100      5.92G     0.8747     0.4993     0.8622         86        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.923      0.916      0.954      0.703
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.923      0.916      0.954      0.703
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      5.87G     0.8703     0.4943     0.8635         93        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.922      0.894      0.944      0.767
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.922      0.894      0.944      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100       5.8G     0.8518     0.4839     0.8564         84        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3ss
#      18/100       5.8G     0.8518     0.4839     0.8564         84        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.919      0.916      0.952      0.724
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.919      0.916      0.952      0.724
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      5.82G     0.8433     0.4709     0.8559        122        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#      19/100      5.82G     0.8433     0.4709     0.8559        122        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.923      0.924      0.953      0.761
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.923      0.924      0.953      0.761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      5.85G     0.8265     0.4658     0.8525         80        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#      20/100      5.85G     0.8265     0.4658     0.8525         80        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.937      0.934      0.963      0.763
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.937      0.934      0.963      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      5.83G      0.816     0.4637     0.8463        104        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.4s0.3ss
#      21/100      5.83G      0.816     0.4637     0.8463        104        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.951      0.922      0.957      0.741
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.951      0.922      0.957      0.741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      5.85G     0.8061     0.4565     0.8514         71        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.942      0.932      0.963      0.766
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.942      0.932      0.963      0.766
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      5.84G     0.8069      0.457     0.8446        155        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.4ss
#      23/100      5.84G     0.8069      0.457     0.8446        155        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.944      0.905      0.959      0.771
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.944      0.905      0.959      0.771
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      5.89G     0.8007     0.4549     0.8427        111        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.932      0.918      0.952      0.746
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.932      0.918      0.952      0.746
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      5.85G     0.7711     0.4428       0.84        117        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.947      0.916      0.959      0.765
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.947      0.916      0.959      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100       5.8G     0.7897     0.4441     0.8388        104        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.954      0.921      0.966      0.798
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.954      0.921      0.966      0.798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100       5.8G     0.7577     0.4276      0.837         71        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3ss
#      27/100       5.8G     0.7577     0.4276      0.837         71        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.961      0.928      0.963       0.76
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.961      0.928      0.963       0.76
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      5.81G     0.7507     0.4421     0.8365         57        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3ss
#      28/100      5.81G     0.7507     0.4421     0.8365         57        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.8s0.3s
#                    all        202       3023      0.954       0.93      0.972      0.798
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.8s
#                    all        202       3023      0.954       0.93      0.972      0.798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      5.81G     0.7501     0.4293     0.8352         93        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.3ss
#      29/100      5.81G     0.7501     0.4293     0.8352         93        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.967      0.902      0.961      0.767
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.967      0.902      0.961      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      5.83G     0.7495     0.4214     0.8318         95        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#      30/100      5.83G     0.7495     0.4214     0.8318         95        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.954      0.938      0.967      0.786
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.954      0.938      0.967      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      5.82G     0.7488     0.4183     0.8308        107        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.4s0.4ss
#      31/100      5.82G     0.7488     0.4183     0.8308        107        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.4s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.957      0.928      0.963      0.774
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.957      0.928      0.963      0.774
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      5.95G     0.7427     0.4157      0.832        126        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.9s0.3s
#                    all        202       3023      0.943       0.92      0.963      0.786
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.9s
#                    all        202       3023      0.943       0.92      0.963      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      5.83G      0.719     0.4117     0.8324         57        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3ss
#      33/100      5.83G      0.719     0.4117     0.8324         57        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.935      0.947      0.966      0.769
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.935      0.947      0.966      0.769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      5.84G     0.7367     0.4161     0.8279         89        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.936       0.93      0.966      0.796
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.936       0.93      0.966      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      5.84G     0.7324     0.4053      0.832         83        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.4s0.3ss
#      35/100      5.84G     0.7324     0.4053      0.832         83        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.8s0.3s
#                    all        202       3023       0.93      0.949      0.971      0.782
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.8s
#                    all        202       3023       0.93      0.949      0.971      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      5.81G      0.728      0.404     0.8254        145        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.963      0.944      0.975      0.786
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.963      0.944      0.975      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      5.83G     0.7067     0.3964     0.8253        108        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#      37/100      5.83G     0.7067     0.3964     0.8253        108        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.967      0.939       0.97      0.811
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.967      0.939       0.97      0.811
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      5.86G     0.7015     0.4013     0.8268         83        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s0.3s
#                    all        202       3023      0.948      0.943      0.965      0.781
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s
#                    all        202       3023      0.948      0.943      0.965      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      5.81G     0.6901     0.3926     0.8231        148        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.4ss
#      39/100      5.81G     0.6901     0.3926     0.8231        148        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.962      0.926      0.968      0.786
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.962      0.926      0.968      0.786
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      5.94G     0.6987     0.3894     0.8254        121        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#      40/100      5.94G     0.6987     0.3894     0.8254        121        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.953       0.94      0.971      0.799
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.953       0.94      0.971      0.799
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      5.82G     0.7024     0.3916     0.8241        110        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.6s0.3ss
#      41/100      5.82G     0.7024     0.3916     0.8241        110        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.957      0.948      0.971      0.785
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.957      0.948      0.971      0.785
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      5.81G     0.6941     0.3895     0.8225        130        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.975      0.937      0.978      0.828
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.975      0.937      0.978      0.828
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      5.81G     0.6891     0.3801     0.8219        101        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#      43/100      5.81G     0.6891     0.3801     0.8219        101        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s0.3s
#                    all        202       3023      0.962       0.94      0.971      0.771
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s
#                    all        202       3023      0.962       0.94      0.971      0.771
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      5.85G     0.6723     0.3826     0.8214         97        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.4s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.955       0.95      0.975      0.807
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.955       0.95      0.975      0.807
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      5.84G     0.6723     0.3749     0.8215        103        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3ss
#      45/100      5.84G     0.6723     0.3749     0.8215        103        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.961      0.954       0.97      0.808
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.961      0.954       0.97      0.808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      5.81G     0.6706     0.3695     0.8158         93        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.3ss
#      46/100      5.81G     0.6706     0.3695     0.8158         93        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.968      0.947      0.972      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      5.82G     0.5035     0.2822     0.7969         99        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#      85/100      5.82G     0.5035     0.2822     0.7969         99        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s0.3s
#                    all        202       3023      0.965      0.947      0.976      0.844
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s
#                    all        202       3023      0.965      0.947      0.976      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      5.82G     0.4928     0.2791     0.7955        109        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#      86/100      5.82G     0.4928     0.2791     0.7955        109        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s0.3s
#                    all        202       3023       0.97       0.94      0.975      0.854
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.8s
#                    all        202       3023       0.97       0.94      0.975      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      5.83G     0.4929     0.2772     0.7951        134        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.4ss
#      87/100      5.83G     0.4929     0.2772     0.7951        134        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.8s0.3s
#                    all        202       3023      0.963      0.942      0.973       0.85
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.8s
#                    all        202       3023      0.963      0.942      0.973       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      5.89G     0.4815     0.2717     0.7932        100        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3ss
#      88/100      5.89G     0.4815     0.2717     0.7932        100        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023       0.96      0.955      0.972      0.843
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023       0.96      0.955      0.972      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      5.83G     0.4931     0.2737     0.7944         70        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.4s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.965      0.949      0.972      0.852
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.965      0.949      0.972      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      5.82G     0.4792      0.268     0.7913        132        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3ss
#      90/100      5.82G     0.4792      0.268     0.7913        132        640: 100% ━━━━━━━━━━━━ 89/89 2.3it/s 38.3s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.968      0.946      0.973      0.851
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.968      0.946      0.973      0.851
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      5.83G      0.446     0.2516     0.7879         68        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.6s0.3ss
#      91/100      5.83G      0.446     0.2516     0.7879         68        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.964      0.943      0.973      0.845
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.964      0.943      0.973      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      5.82G     0.4414     0.2479     0.7866         69        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.8s0.3ss
#      92/100      5.82G     0.4414     0.2479     0.7866         69        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.967       0.95      0.974      0.853
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.967       0.95      0.974      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      5.83G     0.4386     0.2445     0.7872         66        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.9s0.3ss
#      93/100      5.83G     0.4386     0.2445     0.7872         66        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.9s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.968      0.949      0.972      0.848
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.968      0.949      0.972      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      5.82G     0.4272     0.2419     0.7857         55        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.5s0.3ss
#      94/100      5.82G     0.4272     0.2419     0.7857         55        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.5s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.962      0.953      0.971      0.856
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.962      0.953      0.971      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      5.82G     0.4265     0.2398     0.7879         68        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.8s0.4ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.969      0.951      0.972       0.85
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.969      0.951      0.972       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      5.92G     0.4236       0.24     0.7848         40        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.7s0.3ss
#      96/100      5.92G     0.4236       0.24     0.7848         40        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.966      0.954      0.971      0.852
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.966      0.954      0.971      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      5.82G       0.42     0.2362     0.7847         52        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.7s0.3ss
#      97/100      5.82G       0.42     0.2362     0.7847         52        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.9s0.3s
#                    all        202       3023       0.97      0.953      0.973      0.856
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.4it/s 3.9s
#                    all        202       3023       0.97      0.953      0.973      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      5.82G      0.417     0.2355      0.785         59        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.7s0.3ss
#      98/100      5.82G      0.417     0.2355      0.785         59        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.7s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.959      0.959      0.973      0.854
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.959      0.959      0.973      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      5.82G     0.4098      0.232      0.783         63        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.8s0.3ss
#      99/100      5.82G     0.4098      0.232      0.783         63        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.8s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.967      0.959      0.974      0.858
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.967      0.959      0.974      0.858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      5.83G      0.404     0.2288     0.7847         59        640: 100% ━━━━━━━━━━━━ 89/89 2.4it/s 37.7s0.3ss
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s0.3s
#                    all        202       3023      0.967      0.959      0.975      0.859
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.5it/s 3.7s
#                    all        202       3023      0.967      0.959      0.975      0.859
#
# 100 epochs completed in 1.182 hours.
#
# 100 epochs completed in 1.182 hours.
# Optimizer stripped from C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640\weights\last.pt, 40.8MB
# Optimizer stripped from C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640\weights\last.pt, 40.8MB
# Optimizer stripped from C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640\weights\best.pt, 40.8MB
#
# Validating C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640\weights\best.pt...
# Ultralytics 8.3.221  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Optimizer stripped from C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640\weights\best.pt, 40.8MB
#
# Validating C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640\weights\best.pt...
# Ultralytics 8.3.221  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLOv12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 67.1 GFLOPs
# YOLOv12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 67.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.1it/s 4.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.1it/s 4.1s
#                    all        202       3023      0.967      0.959      0.975       0.86
#             goalkeeper        168        168      0.956      0.946      0.971      0.847
#                 player        202       2624      0.979      0.975      0.988      0.901
#                referee        157        231      0.967      0.957      0.967      0.831
# Speed: 0.1ms preprocess, 5.0ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640
#                    all        202       3023      0.967      0.959      0.975       0.86
#             goalkeeper        168        168      0.956      0.946      0.971      0.847
#                 player        202       2624      0.979      0.975      0.988      0.901
#                referee        157        231      0.967      0.957      0.967      0.831
# Speed: 0.1ms preprocess, 5.0ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640

# %%
# Get the run directory path
RUN_DIR = results.save_dir
print(f"📁 Run directory: {RUN_DIR}")
print(f"📊 Training complete!")
print(f"🏆 Best model saved at: {os.path.join(RUN_DIR, 'weights', 'best.pt')}")
# Out:
# 📁 Run directory: C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640
# 📊 Training complete!
# 🏆 Best model saved at: C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640\weights\best.pt

# %%
from IPython.display import Image, display
# Mostra matriz de confusão
display(Image(filename=f"{RUN_DIR}/confusion_matrix.png", width=600))

# %%
from IPython.display import Image, display
# Mostra gráfico de resultados (losses/mAP)
display(Image(filename=f"{RUN_DIR}/results.png", width=600))

# %%
from IPython.display import Image, display
# Mostra predições do batch de validação
display(Image(filename=f"{RUN_DIR}/val_batch0_pred.jpg", width=600))

# %% [markdown]
# ## Validate custom model

# %%
# Validação usando a API Python (evita problemas de CLI e paths com espaços)
metrics = model.val(data=DATA_YAML, imgsz=640, batch=8, device=0, workers=0)
print(f"\n📊 MÉTRICAS FINAIS:")
print(f"mAP50:      {metrics.box.map50:.3f} ({metrics.box.map50*100:.1f}%)")
print(f"mAP50-95:   {metrics.box.map:.3f} ({metrics.box.map*100:.1f}%)")
# Out:
# Ultralytics 8.3.221  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLOv12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 67.1 GFLOPs
# YOLOv12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 67.1 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 1037.7641.5 MB/s, size: 166.2 KB)
# val: Scanning C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1\valid\labels.cache... 202 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 202/202  0.0sval: Fast image access  (ping: 0.00.0 ms, read: 1037.7641.5 MB/s, size: 166.2 KB)
# val: Scanning C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1\valid\labels.cache... 202 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 202/202  0.0s
# val: Scanning C:\_FOOTAR\Player Detection\datasets_and_models\football-players-and-ball-1\valid\labels.cache... 202 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 202/202  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 5.4it/s 4.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 5.4it/s 4.8s
#                    all        202       3194      0.726       0.72      0.732      0.646
#                   ball        156        171          0          0          0          0
#             goalkeeper        168        168      0.955      0.946      0.971      0.847
#                 player        202       2624       0.98      0.976      0.989      0.907
#                referee        157        231      0.968      0.957      0.967      0.831
# Speed: 0.2ms preprocess, 9.1ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\val4
#
# 📊 MÉTRICAS FINAIS:
# mAP50:      0.732 (73.2%)
# mAP50-95:   0.646 (64.6%)
#                    all        202       3194      0.726       0.72      0.732      0.646
#                   ball        156        171          0          0          0          0
#             goalkeeper        168        168      0.955      0.946      0.971      0.847
#                 player        202       2624       0.98      0.976      0.989      0.907
#                referee        157        231      0.968      0.957      0.967      0.831
# Speed: 0.2ms preprocess, 9.1ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\val4
#
# 📊 MÉTRICAS FINAIS:
# mAP50:      0.732 (73.2%)
# mAP50-95:   0.646 (64.6%)

# %%
import shutil
import os
import csv

# Determina qual epoch usar (melhor ou último)
results_csv = os.path.join(RUN_DIR, "results.csv")
with open(results_csv, 'r') as f:
    reader = csv.DictReader(f)
    rows = list(reader)

best_map50 = max(float(r['metrics/mAP50(B)']) for r in rows)
best_epoch = [i+1 for i, r in enumerate(rows) if float(r['metrics/mAP50(B)']) == best_map50][0]

# Caminhos
weights_dir = os.path.join(RUN_DIR, "weights")
best_weights = os.path.join(weights_dir, "best.pt")
data_dir = os.path.join(HOME, "..", "data")
os.makedirs(data_dir, exist_ok=True)

destination = os.path.join(data_dir, "player_y12l_8gb_best.pt")

# Copia
shutil.copy2(best_weights, destination)

print("=" * 60)
print("✅ MODELO COPIADO PARA PRODUÇÃO")
print("=" * 60)
print(f"Origem:  {best_weights}")
print(f"Destino: {destination}")
print(f"\n📝 PRÓXIMO PASSO:")
print(f"   Atualizar main.py linha ~45:")
print(f"   PLAYER_DETECTION_MODEL_PATH = 'data/player_y12l_8gb_best.pt'")
print(f"\n🎯 Melhor época foi: {best_epoch}")
if best_epoch < len(rows):
    print(f"   ⚠️ Se quiser usar epoch {best_epoch} especificamente:")
    epoch_file = f"epoch{best_epoch}.pt"
    if os.path.exists(os.path.join(weights_dir, epoch_file)):
        print(f"   Copiar: {os.path.join(weights_dir, epoch_file)}")
print("=" * 60)
# Out:
# ============================================================
# ✅ MODELO COPIADO PARA PRODUÇÃO
# ============================================================
# Origem:  C:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\runs\detect\player_y12m_footar_640\weights\best.pt
# Destino: c:\_FOOTAR\Player Detection\roboflow_sports_footar\notebooks\..\data\player_y12l_8gb_best.pt
#
# 📝 PRÓXIMO PASSO:
#    Atualizar main.py linha ~45:
#    PLAYER_DETECTION_MODEL_PATH = 'data/player_y12l_8gb_best.pt'
#
# 🎯 Melhor época foi: 42
#    ⚠️ Se quiser usar epoch 42 especificamente:
# ============================================================

# %% [markdown]
# ## Copy optimized model to production
#
# Copia o modelo treinado para o diretório `data/` onde o `main.py` espera encontrá-lo.

# %%
import shutil

# Copy the best trained model to data/ directory
SOURCE_MODEL = os.path.join(RUN_DIR, 'weights', 'best.pt')
TARGET_MODEL = r'C:\_FOOTAR\Player Detection\roboflow_sports_footar\data\player_y12l_footar_best.pt'

if os.path.exists(SOURCE_MODEL):
    shutil.copy2(SOURCE_MODEL, TARGET_MODEL)
    print(f"✅ Model copied to: {TARGET_MODEL}")
    print(f"📊 Model size: {os.path.getsize(TARGET_MODEL) / (1024**2):.1f} MB")
else:
    print(f"❌ Source model not found: {SOURCE_MODEL}")

# Summary
print("\n" + "="*60)
print("🎯 TRAINING SUMMARY")
print("="*60)
print(f"✅ Dataset: FOOTAR football-players-and-ball-1")
print(f"✅ Classes: 4 (ball, goalkeeper, player, referee)")
print(f"✅ Train images: 708")
print(f"✅ Model: YOLOv12l (43M params)")
print(f"✅ Training config: batch=2, imgsz=1280, epochs=100")
print(f"✅ Optimizer: SGD (lr0=0.01, momentum=0.937)")
print(f"✅ Best model: {TARGET_MODEL}")
print("="*60)

# Next steps
print("\n📌 NEXT STEPS:")
print("1. Check mAP50 and mAP50-95 metrics in results")
print("2. Update main.py with new model path:")
print(f"   PLAYER_DETECTION_MODEL_PATH = 'data/player_y12l_footar_best.pt'")
print("3. Test in RADAR mode with new 4-class detection")
print("4. Validate ball + player + goalkeeper + referee detection")
# Out:
# ✅ Model copied to: C:\_FOOTAR\Player Detection\roboflow_sports_footar\data\player_y12l_footar_best.pt
# 📊 Model size: 38.9 MB
#
# ============================================================
# 🎯 TRAINING SUMMARY
# ============================================================
# ✅ Dataset: FOOTAR football-players-and-ball-1
# ✅ Classes: 4 (ball, goalkeeper, player, referee)
# ✅ Train images: 708
# ✅ Model: YOLOv12l (43M params)
# ✅ Training config: batch=2, imgsz=1280, epochs=100
# ✅ Optimizer: SGD (lr0=0.01, momentum=0.937)
# ✅ Best model: C:\_FOOTAR\Player Detection\roboflow_sports_footar\data\player_y12l_footar_best.pt
# ============================================================
#
# 📌 NEXT STEPS:
# 1. Check mAP50 and mAP50-95 metrics in results
# 2. Update main.py with new model path:
#    PLAYER_DETECTION_MODEL_PATH = 'data/player_y12l_footar_best.pt'
# 3. Test in RADAR mode with new 4-class detection
# 4. Validate ball + player + goalkeeper + referee detection

# %% [markdown]
# ## Optional: Deploy model on Roboflow (YOLOv8 only)
#
# Note: Roboflow's deploy(model_type="yolov8") currently requires ultralytics==8.0.196. This notebook trains with YOLOv12 on ultralytics 8.3.x, so deploying from here will fail. You can:
# - Upload the weights file manually in the Roboflow UI (Versions -> Upload Model -> YOLOv8) using RUN_DIR/weights/best.pt
# - Or create a separate env with ultralytics==8.0.196 and run the deploy cell there.

# %%
'''
# Guarded deploy: skip if ultralytics version is not the one required by Roboflow's deploy
import os
import ultralytics as ulx

# Resolve RUN_DIR and WEIGHTS path safely
try:
    RUN_DIR
except NameError:
    import glob
    base = os.path.join(HOME, "runs", "detect")
    # fallback: pick most recent detect run
    candidates = glob.glob(os.path.join(base, "*"))
    candidates = [p for p in candidates if os.path.isdir(p)]
    RUN_DIR = max(candidates, key=os.path.getmtime) if candidates else None

if RUN_DIR is None:
    print("No run directory found; train the model first.")
else:
    weights_path = os.path.join(RUN_DIR, "weights", "best.pt")
    need = "8.0.196"
    have = ulx.__version__
    if have == need:
        print(f"Deploying {weights_path} to Roboflow as YOLOv8 with ultralytics {have}...")
        project.version(dataset.version).deploy(model_type="yolov8", model_path=weights_path)
    else:
        print(f"Skipping deploy: Roboflow requires ultralytics=={need}, but found {have}.")
        print("Options:")
        print("  1) Upload manually in Roboflow UI: Versions -> Upload Model -> YOLOv8")
        print(f"     Weights: {weights_path}")
        print("  2) Create a separate env with ultralytics==8.0.196 and run this cell there.")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.2.63, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/10
# Share your model with the world at: https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/model/10
